# %%
import json
from utils import display_summary_stats, display_detailed_stats

# %% [markdown]
# # Caligraph experiments

# %%
experiments = [
    ("google/gemma-2b-it", json.load(open('gemma-2b-it-caligraph.json', 'r'))),
    ("google/gemma-7b-it", json.load(open('gemma-7b-it-caligraph.json', 'r'))),
    ("gpt-3.5-turbo", json.load(open('gpt-3.5-turbo-caligraph.json', 'r'))),
    ("gpt-4-0125-preview", json.load(open('gpt-4-0125-preview-caligraph.json', 'r'))),
    ("mistralai/Mistral-7B-Instruct-v0.2", json.load(open('Mistral-7B-Instruct-v0.2-caligraph.json', 'r'))),
    ("mistralai/Mixtral-8x7B-Instruct-v0.1", json.load(open('Mixtral-8x7B-Instruct-v0.1-caligraph.json', 'r'))),
    ("meta-llama/Llama-2-70b-chat-hf", json.load(open('Llama-2-70b-chat-hf-caligraph.json', 'r')))
]

# %% [markdown]
# ## Comparison of model performance

# %%
display_summary_stats(experiments)
# Out:
# <style type="text/css">
# #T_6e179_row0_col1, #T_6e179_row0_col2, #T_6e179_row0_col3, #T_6e179_row0_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_6e179">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e179_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6e179_level0_col1" class="col_heading level0 col1" >ACC</th>
#       <th id="T_6e179_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_6e179_level0_col3" class="col_heading level0 col3" >F1 Macro</th>
#       <th id="T_6e179_level0_col4" class="col_heading level0 col4" >Cohen's kappa</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e179_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_6e179_row0_col0" class="data row0 col0" >gpt-4-0125-preview</td>
#       <td id="T_6e179_row0_col1" class="data row0 col1" >0.899957</td>
# ...

# %% [markdown]
# ## Model performance in detail

# %%
for experiment in experiments:
    display_detailed_stats(experiment)
# Out:
# ## Model: google/gemma-2b-it
# ### Performance metrics
# #### By concept
#                                               concept       ACC       AUC  \
# 0                          Argentine football manager  0.657895  0.638889
# 1                       Populated place in Luxembourg  0.525000  0.525000
# 2                     Single-camera television sitcom  0.500000  0.500000
# 3                                State leader in 2014  0.578947  0.555556
# 4                               Hill station in India  0.685714  0.633333
# 5                        Newspaper in New South Wales  0.575000  0.575000
# 6                                  FK Sarajevo player  0.500000  0.500000
# 7             Medalist at the 2019 Summer Universiade  0.500000  0.500000
# 8            Romania international rugby union player  0.500000  0.500000
# 9                                           1921 film  0.550000  0.550000
# 10           Player of American football from Alabama  0.500000  0.500000
# ...
