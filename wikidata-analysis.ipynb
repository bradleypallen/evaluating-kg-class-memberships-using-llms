# %%
import json
from utils import display_summary_stats, display_detailed_stats

# %% [markdown]
# # Wikidata experiments

# %%
experiments = [
    ("google/gemma-2b-it", json.load(open('gemma-2b-it-wikidata.json', 'r'))),
    ("google/gemma-7b-it", json.load(open('gemma-7b-it-wikidata.json', 'r'))),
    ("gpt-3.5-turbo", json.load(open('gpt-3.5-turbo-wikidata.json', 'r'))),
    ("gpt-4-0125-preview", json.load(open('gpt-4-0125-preview-wikidata.json', 'r'))),
    ("mistralai/Mistral-7B-Instruct-v0.2", json.load(open('Mistral-7B-Instruct-v0.2-wikidata.json', 'r'))),
    ("mistralai/Mixtral-8x7B-Instruct-v0.1", json.load(open('Mixtral-8x7B-Instruct-v0.1-wikidata.json', 'r'))),
    ("meta-llama/Llama-2-70b-chat-hf", json.load(open('Llama-2-70b-chat-hf-wikidata.json', 'r'))),
]

# %% [markdown]
# ## Comparison of model performance

# %%
display_summary_stats(experiments)
# Out:
# <style type="text/css">
# #T_118b9_row0_col1, #T_118b9_row0_col2, #T_118b9_row0_col3, #T_118b9_row0_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_118b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_118b9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_118b9_level0_col1" class="col_heading level0 col1" >ACC</th>
#       <th id="T_118b9_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_118b9_level0_col3" class="col_heading level0 col3" >F1 Macro</th>
#       <th id="T_118b9_level0_col4" class="col_heading level0 col4" >Cohen's kappa</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_118b9_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_118b9_row0_col0" class="data row0 col0" >gpt-4-0125-preview</td>
#       <td id="T_118b9_row0_col1" class="data row0 col1" >0.830000</td>
# ...

# %% [markdown]
# ## Model performance in detail

# %%
for experiment in experiments:
    display_detailed_stats(experiment)
# Out:
# ## Model: google/gemma-2b-it
# ### Performance metrics
# #### By concept
#                                concept       ACC       AUC  F1 Macro  \
# 0                    History of cities  0.631579  0.631579  0.614493
# 1                      Embedded system  0.378378  0.388889  0.274510
# 2                     Irregular galaxy  0.487179  0.500000  0.327586
# 3                  Plant variety (law)  0.378378  0.402941  0.329393
# 4                        Microcomputer  0.513514  0.501462  0.383333
# 5                     Equestrian sport  0.742857  0.718750  0.708603
# 6                                Fraud  0.742857  0.735294  0.720000
# 7                             Seaplane  0.857143  0.708333  0.708333
# 8                      Beer in Belgium  0.638889  0.668750  0.624699
# 9                       Seyfert galaxy  0.571429  0.560458  0.489796
# 10                     Cities of Japan  0.769231  0.775000  0.759094
# ...
